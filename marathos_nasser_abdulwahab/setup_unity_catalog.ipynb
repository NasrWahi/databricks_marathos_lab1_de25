-- %% [markdown]
-- # Setup Unity Catalog for Marathos
--
-- This notebook creates the catalog, schemas and volume required by the lab.

-- %%
CREATE CATALOG IF NOT EXISTS marathos;

USE CATALOG marathos;

CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;

CREATE VOLUME IF NOT EXISTS marathos.default.raw;

-- %%
%python
# Uploading dataset through the Catalog UI
dbutils.fs.mkdirs("/Volumes/marathos/default/raw/data")

-- %%
-- Check the CSV file in the volume
LIST '/Volumes/marathos/default/raw/data'
